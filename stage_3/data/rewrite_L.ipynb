# %%
import pandas as pd

# %%
table_l = 'L.csv'

dfl = pd.read_csv(table_l)
dfl.head()
# Out:
#    A_id  B_id  _id_l                                             name_l  \
# 0   823   663    823                               Jumanji (1995) (DVD)
# 1   977   231    977                         The Last Starfighter (DVD)
# 2  2622  2009   2622                              The Jungle Book (DVD)
# 3  2710    25   2710  Ace Ventura: Pet Detective & When Nature Calls...
# 4   262  1277    262          The Hunger Games: Mockingjay Part 2 (DVD)
#
#   duration_l                                            genre_l  \
# 0    104 min                                 Action & Adventure
# 1    101 min                                             Horror
# 2    106 min  Kids & Family, Action & Adventure, Anime & Ani...
# 3    180 min                                   Sci-Fi & Fantasy
# 4    113 min                          Drama, Action & Adventure
#
#   release_date_l                  directors_l  \
# 0            NaN                 Joe Johnston
# 1        8/18/09             Nick Castle, Jr.
# ...

# %%
l_label = dfl[['A_id', 'B_id', 'label']]
l_label.head()
# Out:
#    A_id  B_id  label
# 0   823   663      1
# 1   977   231      0
# 2  2622  2009      0
# 3  2710    25      1
# 4   262  1277      0

# %%
l_label.to_csv('labeled_L.csv', index=0)
