# %% [markdown]
# # Prep 1: steps to install the packages

# %%
# !pip install py_entitymatching==0.2.0
# !pip install scipy
# !pip install numpy
# !pip install pandas
# Out:
# Collecting py_entitymatching==0.2.0
#   Downloading https://files.pythonhosted.org/packages/d8/e7/0d89a09da15eca81ae5babfd420e299a57bdcf7cef18fa9a398aaafd3c1d/py_entitymatching-0.2.0.tar.gz (1.9MB)
#     100% |████████████████████████████████| 2.0MB 55kB/s ta 0:00:013
# Requirement already satisfied: PyPrind in /anaconda3/lib/python3.6/site-packages (from py_entitymatching==0.2.0) (2.11.2)
# Collecting py_stringsimjoin==0.1.0 (from py_entitymatching==0.2.0)
#   Downloading https://files.pythonhosted.org/packages/e9/d2/3191735fd23e0b92da17e7a4a4de9e2c9d220eec2ae0fdc55168f46a9c3a/py_stringsimjoin-0.1.0.tar.gz (352kB)
#     100% |████████████████████████████████| 358kB 25kB/s ta 0:00:01
# Requirement already satisfied: cloudpickle>=0.2.1 in /anaconda3/lib/python3.6/site-packages (from py_entitymatching==0.2.0) (0.6.1)
# Requirement already satisfied: pyparsing>=2.1.4 in /anaconda3/lib/python3.6/site-packages (from py_entitymatching==0.2.0) (2.3.1)
# Requirement already satisfied: scikit-learn>=0.18 in /anaconda3/lib/python3.6/site-packages (from py_entitymatching==0.2.0) (0.19.0)
# Collecting pandas-profiling>=1.4.0 (from py_entitymatching==0.2.0)
# Requirement already satisfied: joblib in /anaconda3/lib/python3.6/site-packages (from py_stringsimjoin==0.1.0->py_entitymatching==0.2.0) (0.13.2)
# Requirement already satisfied: pandas>=0.16.0 in /anaconda3/lib/python3.6/site-packages (from py_stringsimjoin==0.1.0->py_entitymatching==0.2.0) (0.24.0)
# Requirement already satisfied: py_stringmatching>=0.2.1 in /anaconda3/lib/python3.6/site-packages (from py_stringsimjoin==0.1.0->py_entitymatching==0.2.0) (0.4.1)
# Requirement already satisfied: six in /anaconda3/lib/python3.6/site-packages (from py_stringsimjoin==0.1.0->py_entitymatching==0.2.0) (1.12.0)
# Requirement already satisfied: matplotlib>=1.4 in /anaconda3/lib/python3.6/site-packages (from pandas-profiling>=1.4.0->py_entitymatching==0.2.0) (3.0.2)
# Requirement already satisfied: jinja2>=2.8 in /anaconda3/lib/python3.6/site-packages (from pandas-profiling>=1.4.0->py_entitymatching==0.2.0) (2.10)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.6/site-packages (from pandas>=0.16.0->py_stringsimjoin==0.1.0->py_entitymatching==0.2.0) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.6/site-packages (from pandas>=0.16.0->py_stringsimjoin==0.1.0->py_entitymatching==0.2.0) (2.7.5)
# Requirement already satisfied: numpy>=1.12.0 in /anaconda3/lib/python3.6/site-packages (from pandas>=0.16.0->py_stringsimjoin==0.1.0->py_entitymatching==0.2.0) (1.15.4)
# Requirement already satisfied: cycler>=0.10 in /anaconda3/lib/python3.6/site-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching==0.2.0) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /anaconda3/lib/python3.6/site-packages (from matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching==0.2.0) (1.0.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /anaconda3/lib/python3.6/site-packages (from jinja2>=2.8->pandas-profiling>=1.4.0->py_entitymatching==0.2.0) (1.1.0)
# Requirement already satisfied: setuptools in /anaconda3/lib/python3.6/site-packages (from kiwisolver>=1.0.1->matplotlib>=1.4->pandas-profiling>=1.4.0->py_entitymatching==0.2.0) (40.6.3)
# Building wheels for collected packages: py-entitymatching, py-stringsimjoin
#   Running setup.py bdist_wheel for py-entitymatching ... done
#   Stored in directory: /Users/datachat/Library/Caches/pip/wheels/db/e0/dd/1289587d181b95ed55eed1d6692e18661bad83aa681e6a169c
#   Running setup.py bdist_wheel for py-stringsimjoin ... done
#   Stored in directory: /Users/datachat/Library/Caches/pip/wheels/53/2d/b5/af1765deb8587519f5460027922ad641cbac6dcce0842f7dde
# Successfully built py-entitymatching py-stringsimjoin
# Installing collected packages: py-stringsimjoin, pandas-profiling, py-entitymatching
# Successfully installed pandas-profiling-1.4.2 py-entitymatching-0.2.0 py-stringsimjoin-0.1.0
# Requirement already satisfied: scipy in /anaconda3/lib/python3.6/site-packages (1.2.0)
# Requirement already satisfied: numpy in /anaconda3/lib/python3.6/site-packages (1.15.4)
# Requirement already satisfied: pandas in /anaconda3/lib/python3.6/site-packages (0.24.0)
# Requirement already satisfied: pytz>=2011k in /anaconda3/lib/python3.6/site-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.12.0 in /anaconda3/lib/python3.6/site-packages (from pandas) (1.15.4)
# Requirement already satisfied: python-dateutil>=2.5.0 in /anaconda3/lib/python3.6/site-packages (from pandas) (2.7.5)
# Requirement already satisfied: six>=1.5 in /anaconda3/lib/python3.6/site-packages (from python-dateutil>=2.5.0->pandas) (1.12.0)

# %% [markdown]
# # [NEED MODIFICATION: Modify this cell to point to the file location]
# # Prep 2: enter the file location on your harddisk

# %%
table_a = 'Walmart.csv'
table_b = 'IMDB.csv'
candidate_set = 'reduced_candidate.csv'
prediction_set = '777_cm_matching_al_ds.csv'

# %% [markdown]
# # Prep 3: reading the files into pandas dataframe

# %%
import pandas as pd
dfa = pd.read_csv(table_a)
dfb = pd.read_csv(table_b)
dfc = pd.read_csv(candidate_set)
dfp = pd.read_csv(prediction_set)

# %%
dfp.head()
# Out:
#     id1   id2  matching_probability
# 0    10  2429                  0.70
# 1  1003  2072                  0.90
# 2  1005   745                  0.95
# 3  1008   282                  1.00
# 4  1012   457                  1.00

# %% [markdown]
# # Module: debug_blocker
# # Description: debug the blocking rule using the below script to ensure you are not dropping true matches
# # Note: You need to run Prep 1 and 2 in order to run this

# %%
# Example input format:
# Format of table_a:
# _id, attribute1, attribute2, ....., attributen

# Format of table_b:
# _id, attribute1, attribute2, ....., attributen

# Format of candidate_set
# A_id,B_id
# where A_id is _id from table_a and B_id is the _id column value from table_b

# %%
import py_entitymatching as em
import pandas as pd

def run_debug_blocker(table_a, table_b, table_a_key, table_b_key, candidate_set):
    dfl = em.read_csv_metadata(table_a, key=table_a_key)
    dfr = em.read_csv_metadata(table_b, key=table_b_key)

    # reading the candidate set and adding key
    dfcand = pd.read_csv(candidate_set)
    dfcand.drop_duplicates(inplace=True)
    dfcand.to_csv('cand_set_with_index.csv', index_label='id')

    dfcset = em.read_csv_metadata('cand_set_with_index.csv', key='id', ltable=dfl, 
                                  rtable=dfr, fk_ltable='A_id', fk_rtable='B_id')

    # running debug blocker to identify the records in A x B \ C
    debug_file = em.debug_blocker(dfcset, dfl, dfr)
    
    return debug_file
# Out:
# /anaconda3/lib/python3.6/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
debug_file = run_debug_blocker(table_a, table_b, '_id', '_id', candidate_set)
# Out:
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.
# Metadata file is not present in the given path; proceeding to read the csv file.

# %%
debug_file
# Out:
#      _id  similarity  ltable__id  rtable__id  \
# 0      0    0.714286        2365        1057
# 1      1    0.647059        2495        1133
# 2      2    0.642857        1385         137
# 3      3    0.588235        1606        1775
# 4      4    0.571429         428        2780
# 5      5    0.571429         952         775
# 6      6    0.562500         574        1034
# 7      7    0.550000          31         243
# 8      8    0.529412        2239        1596
# 9      9    0.500000         994         910
# 10    10    0.500000        1935        2681
# 11    11    0.500000         526        2220
# 12    12    0.476190         185          76
# 13    13    0.476190         952        2204
# 14    14    0.473684         601        1133
# 15    15    0.466667        2231        2423
# 16    16    0.461538         666        1118
# 17    17    0.444444        2278        2499
# 18    18    0.444444        1923        2538
# 19    19    0.444444        1877        2787
# 20    20    0.437500         179        1932
# 21    21    0.437500         979        1241
# 22    22    0.437500        1007        2681
# 23    23    0.437500        1870        1446
# 24    24    0.428571        2565        1596
# 25    25    0.423077        1640        1482
# 26    26    0.421053         987        1549
# 27    27    0.413793        2382        1949
# 28    28    0.411765         378        1765
# 29    29    0.411765         491         862
# ..   ...         ...         ...         ...
# 170  170    0.281250         411        1619
# 171  171    0.281250        1327        1417
# 172  172    0.281250        2891         564
# 173  173    0.281250        1253          92
# 174  174    0.280000        2180        2140
# 175  175    0.277778        1007        1932
# 176  176    0.277778         163        2171
# 177  177    0.277778        1195         275
# 176         111 min                                  Animation & Cartoons
# 177          82 min                                     Anime & Animation
# 178         768 min                                    Action & Adventure
# 179         131 min                                    Action & Adventure
# 180             152                                     Anime & Animation
# 181       135 mins.                                    Action & Adventure
# 182          22 min                                         Kids & Family
# 183         152 min                                     Anime & Animation
# 184             NaN                                                Comedy
# 185         111 min                              Sci-Fi & Fantasy, Comedy
# 186         150 min                                    Action & Adventure
# 187             227                                                Comedy
# 188          88 min                 Anime & Animation, Action & Adventure
# 189         109 min                                                 Drama
# 190          64 min                 Action & Adventure, Anime & Animation
# 191          57 min                                         Kids & Family
# 192             144                                                Comedy
# 193             190                                                Comedy
# 194         189 min                                                Comedy
# 195             343                                    Action & Adventure
# 196         110 min                                                Comedy
# 197          77 min                 Action & Adventure, Anime & Animation
# 198         206 min                                                Comedy
# 199             110                                                Comedy
#
#     ltable_release_date            ltable_directors  \
# 0            01/05/2016            Denis Villeneuve
# 1      October 17, 2017                   Jon Watts
# 2            11/25/2008                  Peter Berg
# 3                   NaN               Justin Kurzel
# 4                   NaN                 Tom McGrath
# 5            12/31/2016      Jon Lucas, Scott Moore
# 6            10/13/2015                   Brad Bird
# 7            07/19/2016                 Zack Snyder
# 8            06/09/2015                  Ari Sandel
# 9                   NaN               Otto Bathurst
# 10           08/04/2015            Robert Schwentke
# 11                  NaN                 Ben Falcone
# 12           09/05/2006          Paul W.S. Anderson
# 13           12/31/2016      Jon Lucas, Scott Moore
# 14                  NaN                   Jon Watts
# 15                  NaN                  Luc Besson
# 16                  NaN                Kelly Asbury
# 17                  NaN               Tetsuo Yajima
# 18           03/31/2016          Genndy Tartakovsky
# 19                  NaN          Hans Petter Moland
# 20           07/12/2016            Robert Schwentke
# 21           02/04/2003                         NaN
# 22           07/12/2016            Robert Schwentke
# 23                  NaN                 Tom McGrath
# 24           06/09/2015                  Ari Sandel
# 25                  NaN                 Michael Bay
# 26           02/28/2017            Scott Derrickson
# 27                  NaN         Jordan Vogt-Roberts
# 28           05/05/2015               James Cameron
# 29                  NaN               Jason Reitman
# ..                  ...                         ...
# 170          08/12/2014            Robert Stevenson
# 171                 NaN              Dean Israelite
# 172                 NaN                 Peter Segal
# 173          10/07/2014                         NaN
# 174          03/05/2013                  Rich Moore
# 175          07/12/2016            Robert Schwentke
# 176          09/28/2010                         NaN
# 177                 NaN  John Musker & Ron Clements
# 178                 NaN       Christopher McQuarrie
# 179                 NaN               James Mangold
# 180          01/31/2017                         NaN
# 181          09/24/2013                 Shane Black
# 182          10/01/2013              Gary Trousdale
# 183          06/11/2013  Elliot Bour, Saul Blinkoff
# 184          01/31/2017                 Tyler Perry
# 185                 NaN   Glenn Ficarra, John Requa
# 186          03/01/2011              Gore Verbinski
# 187          01/26/2016                         NaN
# 188          10/02/2012                 Don Chaffey
# 189          05/10/2011          Jean-Pierre Jeunet
# 190          10/09/2001               Jim Stenstrum
# 191          09/06/2011                Greg Tiernan
# 192          02/05/2013                 Tyler Perry
# 193          02/18/2014               Oliver Parker
# 17         1h 37min           Action, Fantasy, Animation, Adventure, Family
# 18         1h 31min              Comedy, Fantasy, Horror, Animation, Family
# 19         1h 59min                          Action, Drama, Thriller, Crime
# 20               2h            Action, Mystery, Adventure, Thriller, Sci-Fi
# 21            30min                                           Drama, Comedy
# 22         1h 59min                     Action, Adventure, Thriller, Sci-Fi
# 23         1h 35min               Action, Animation, Family, Comedy, Sci-Fi
# 24         1h 41min                                         Romance, Comedy
# 25         2h 30min                               Action, Adventure, Sci-Fi
# 26         1h 55min                      Action, Fantasy, Adventure, Sci-Fi
# 27         1h 58min                      Action, Fantasy, Adventure, Sci-Fi
# 28         2h 17min                                          Action, Sci-Fi
# 29         1h 35min                                  Drama, Mystery, Comedy
# ..              ...                                                     ...
# 170        1h 57min  Family, Fantasy, Animation, Adventure, Comedy, Musical
# 171         2h 4min                               Action, Adventure, Sci-Fi
# 172        1h 43min                                  Drama, Romance, Comedy
# 173        1h 27min    Family, Fantasy, Animation, Music, Adventure, Comedy
# 174        1h 51min           Comedy, Fantasy, Animation, Adventure, Family
# 175              2h            Action, Mystery, Adventure, Thriller, Sci-Fi
# 176           22min                                       Comedy, Animation
# 177        1h 23min            Romance, Fantasy, Animation, Musical, Family
# 178        2h 27min                             Action, Adventure, Thriller
# 179        2h 17min                         Action, Drama, Sci-Fi, Thriller
# 180        1h 23min                     Drama, Animation, Adventure, Family
# 181        2h 10min                               Action, Adventure, Sci-Fi
# 182        1h 33min           Comedy, Fantasy, Animation, Adventure, Family
# 183        1h 15min             Comedy, Romance, Animation, Musical, Family
# 184        1h 49min                                                  Comedy
# 185        1h 45min                           Drama, Romance, Comedy, Crime
# 186        2h 49min                              Action, Fantasy, Adventure
# 187        1h 52min                                  Romance, Comedy, Music
# 188         2h 8min  Family, Fantasy, Animation, Adventure, Comedy, Musical
# 189        1h 49min                                  Action, Horror, Sci-Fi
# 190        1h 10min             Comedy, Fantasy, Animation, Family, Mystery
# 191           11min                      Comedy, Fantasy, Animation, Family
# 192        1h 49min                                                  Comedy
# 193        1h 27min                               Action, Comedy, Adventure
# 194        1h 35min           Comedy, Fantasy, Animation, Adventure, Family
# 195        1h 56min                               Comedy, Adventure, Sci-Fi
# 196        1h 50min                                           Comedy, Crime
# 197        1h 18min                   Fantasy, Animation, Adventure, Family
# 198        1h 44min                                       Comedy, Adventure
# 199        1h 48min                      Fantasy, Comedy, Adventure, Family
#
#          rtable_release_date               rtable_directors  \
# 0       2 October 2015 (USA)               Denis Villeneuve
# 1          7 July 2017 (USA)                      Jon Watts
# 2          2 July 2008 (USA)                     Peter Berg
# 3     21 December 2016 (USA)                  Justin Kurzel
# 4        31 March 2017 (USA)                    Tom McGrath
# 5      1 November 2017 (USA)         Jon Lucas, Scott Moore
# 6          22 May 2015 (USA)                      Brad Bird
# 7         14 June 2013 (USA)                    Zack Snyder
# 8     20 February 2015 (USA)                     Ari Sandel
# 9     21 November 2018 (USA)                  Otto Bathurst
# 10       20 March 2015 (USA)               Robert Schwentke
# 192                Tyler Perry, Cassi Davis, Patrice Lovely               CM
# 193       Rowan Atkinson, John Malkovich, Natalie Imbruglia               CM
# 194           James Corden, Fayssal Bazzi, Domhnall Gleeson               CM
# 195         Michael J. Fox, Christopher Lloyd, Lea Thompson               CM
# 196          Jason Sudeikis, Jennifer Aniston, Emma Roberts               CM
# 197             Mae Whitman, Kristin Chenoweth, Raven-Symon               CM
# 198                  Mila Kunis, Kristen Bell, Kathryn Hahn               CM
# 199                Ben Stiller, Carla Gugino, Ricky Gervais               CM
#
# [200 rows x 18 columns]

# %% [markdown]
# # Module: estimate_precision_recall
# # Description: the below code helps you get an estimation of P/R on the candidate set.

# %%
import pandas as pd
from scipy.stats import norm
from numpy import sqrt

delta = .05
Z = norm.ppf(1 - (delta / 2))

def estimate_PR(labeled_pairs, reduced_cands, predicted_matches):
    '''
    labeled_pairs - a pandas dataframe with schema id1,id2,label
                    Note label needs to be Boolean

    reduced_cands - a pandas dataframe with schema id1,id2
    predicted_matches - a pandas dataframe with schema id1,id2
    
    return:
        ( (recall lower bound, recall upper bound), (precision lower bound, precision upper bound) )
    '''

    labeled_pairs.drop_duplicates(inplace=True)
    labeled_pairs.columns = ['id1', 'id2', 'label']
    reduced_cands.columns = ['id1', 'id2']
    reduced_cand_set = set(zip(reduced_cands.id1, reduced_cands.id2))
    predicted_matches = set(zip(predicted_matches.id1, predicted_matches.id2))
    
    # estimate the recall
    # number of positives in the labeled sample
    actual_pos = float(labeled_pairs.label.sum())
    # the maximum number of postives in the candidate set
    max_actual_pos = float(actual_pos + len(reduced_cand_set) - len(labeled_pairs))
    
    # true positives in the labeled sample
    true_pos = float(labeled_pairs.apply(lambda x : (x['id1'], x['id2']) in predicted_matches and x['label'], axis=1).sum())
    #estimated recall
    recall = float(true_pos / actual_pos)

    recall_error = Z * sqrt( ((recall * (1 - recall)) / (actual_pos)) * ((max_actual_pos - actual_pos) / (max_actual_pos - 1)) )


    # estimate Precision
    labeled_set  = set(zip(labeled_pairs.id1, labeled_pairs.id2))
    predicted_pos = float(len(labeled_set & predicted_matches))
    
    predicted_pos_in_reduced_cand_set = float(len(reduced_cand_set & predicted_matches))
    
    alpha =  predicted_pos_in_reduced_cand_set / len(predicted_matches)
    precision = alpha * (true_pos / predicted_pos)
    
    precision_error = alpha * Z * sqrt( ((precision * (1 - precision)) / predicted_pos) * (float((len(predicted_matches) - predicted_pos)) / (len(predicted_matches)  - 1)) )

    return ((recall - recall_error, recall + recall_error),
            (precision - precision_error, precision + precision_error))

# %% [markdown]
# # [NEED MODIFICATION: Modify this cell to point to the file location]

# %%
# read the labeled pairs file, i.e. the file with the labels
labeled_pairs = pd.read_csv('labeled_L.csv')
print(estimate_PR(labeled_pairs, dfc, dfp))
# Out:
# ((0.8752333717794825, 0.9421182263940335), (0.6021187849327913, 0.6808274785970235))

# %% [markdown]
# # Alternatively if you run into issues running this script on your laptop you can use
# # https://colab.research.google.com/notebooks/welcome.ipynb
